# %%
import pandas as pd
import numpy as np
import os

from tqdm import tqdm
from unicodedata import normalize

tqdm.pandas()
# Out:
# /Users/jalvaradoruiz/opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# # DATA DELITOS

# %%
df_delitos = pd.read_feather("FEATHER_FILES/Delitos_feather")
df_delitos.head()
# Out:
#    index  COD. MATERIA                                            MATERIA  \
# 0      0           101                           QUEBRANTAMIENTO. ART. 90
# 1      1           202                                SECUESTRO. ART. 141
# 2      2           203                   SUSTRACCION DE MENORES. ART. 142
# 3      3           204                       VIOLACION DE MORADA. ART.144
# 4      4           205   APERTURA , REGISTRO O INTERCEPTACION DE CORRE...
#
#                                    TIPOLOGIA MATERIA VIGENCIA MATERIA
# 0  LIBRO I  TITULO IV   QUEBRANTAMIENTO DE SENTEN...          VIGENTE
# 1  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE
# 2  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE
# 3  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE
# 4  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE

# %%
codigos_cot = df_delitos['COD. MATERIA'].unique()
print(f"Existen {len(codigos_cot)} codigos de delitos")
# Out:
# Existen 541 codigos de delitos

# %% [markdown]
# # DATAS INGRESO Y TERMINO MATERIA

# %% [markdown]
# ### DATA INGRESO X MATERA

# %%
df_ingresos_materia = pd.read_feather("FEATHER_FILES/IngresosMateria_feather")
df_ingresos_materia.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                     TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  100-2018  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  100-2018  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  101-2018  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA   10-2018  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  102-2018  Ordinaria
#
#    COD. MATERIA                                            MATERIA  \
# 0          7007                TRAFICO ILICITO DE DROGAS (ART. 3).
# 1         10004  PORTE ILEGAL DE ARMA DE FUEGO, MUNICIONES Y OT...
# 2         12149  DESACATO (ART. 240 CODIGO DE PROCEDIMIENTO CIV...
# 3          7037           TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).
# 4           812                       RECEPTACION. ART. 456 BIS A.
#
#   FECHA INGRESO
# 0    2018-04-02
# 1    2018-04-02
# 2    2018-04-02
# 3    2018-01-10
# 4    2018-04-02

# %%
codigos_delitos = df_ingresos_materia['COD. MATERIA'].unique()

# %%
len(codigos_delitos)
# Out:
# 474

# %%
codigos_no_encontrados = []
for delito in codigos_delitos:
    if not delito in codigos_cot:
        codigos_no_encontrados.append(delito)

# %%
codigos_no_encontrados
# Out:
# [13001, -31075, 0, 4011, 4014, 4013, 4010]

# %%
codigos_sin_registro = df_ingresos_materia[df_ingresos_materia['COD. MATERIA'].isin(codigos_no_encontrados)]

codigos_sin_registro['MATERIA'].unique()
# Out:
# array(['LESIONES LEVES.', 'FALTAS AL REGIMEN PENITENCIARIO', '[NULL]',
#        'MANEJO EN ESTADO DE EBRIEDAD (SOLO CRIMEN)',
#        'ESTAFA (SOLO CRIMEN)', 'ABUSO SEXUAL (SOLO CRIMEN)',
#        'VIOLACION (SOLO CRIMEN)'], dtype=object)

# %% [markdown]
# ### TERMINO X MATERIA

# %%
df_termino_materia = pd.read_feather("FEATHER_FILES/TerminoMateria_feather")
df_termino_materia.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                     TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  100-2018  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  100-2018  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  101-2018  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA   10-2018  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  102-2018  Ordinaria
#
#    COD. MATERIA                                            MATERIA  \
# 0          7007                TRAFICO ILICITO DE DROGAS (ART. 3).
# 1         10004  PORTE ILEGAL DE ARMA DE FUEGO, MUNICIONES Y OT...
# 2         12149  DESACATO (ART. 240 CODIGO DE PROCEDIMIENTO CIV...
# 3          7037           TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).
# 4           812                       RECEPTACION. ART. 456 BIS A.
#
#   FECHA INGRESO FECHA TERMINO MOTIVO TERMINO  DURACION CAUSA
# 0    2018-04-02    2018-06-01      SENTENCIA              60
# 1    2018-04-02    2018-06-01      SENTENCIA              60
# 2    2018-04-02    2018-08-29      SENTENCIA             149
# 3    2018-01-10    2018-03-14      SENTENCIA              63
# 4    2018-04-02    2018-05-29      SENTENCIA              57

# %%
codigos_delitos = df_termino_materia['COD. MATERIA'].unique()

# %%
len(codigos_delitos)
# Out:
# 468

# %%
codigos_no_encontrados = []
for delito in codigos_delitos:
    if not delito in codigos_cot:
        codigos_no_encontrados.append(delito)

# %%
codigos_no_encontrados
# Out:
# [13001, 4014, 4013, 4011, -31075, 4010, 0, 4007]

# %%
codigos_sin_registro = df_termino_materia[df_termino_materia['COD. MATERIA'].isin(codigos_no_encontrados)]

codigos_sin_registro['MATERIA'].unique()
# Out:
# array(['LESIONES LEVES.', 'ESTAFA (SOLO CRIMEN)',
#        'ABUSO SEXUAL (SOLO CRIMEN)',
#        'MANEJO EN ESTADO DE EBRIEDAD (SOLO CRIMEN)',
#        'FALTAS AL REGIMEN PENITENCIARIO', 'VIOLACION (SOLO CRIMEN)',
#        'LESIONES LEVES', '(en blanco)', 'HURTO (SOLO CRIMEN)',
#        'NO REGISTRA CODIGO DE MATERIA'], dtype=object)

# %% [markdown]
# # DATA INGRESO Y TERMINO ROL PENAL

# %% [markdown]
# ### INGRESOS X ROL

# %%
df_ingresos_rol = pd.read_feather("FEATHER_FILES/IngresosRol_feather")
df_ingresos_rol.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                     TRIBUNAL     RIT TIPO CAUSA FECHA INGRESO
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  1-2018  Ordinaria    2018-01-02
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  2-2018  Ordinaria    2018-01-03
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  3-2018  Ordinaria    2018-01-03
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  4-2018  Ordinaria    2018-01-03
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  5-2018  Ordinaria    2018-01-03

# %% [markdown]
# ### TERMINO X ROL

# %%
df_termino_rol = pd.read_feather("FEATHER_FILES/TerminoRol_feather")
df_termino_rol.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                        TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  101-2018  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA   10-2018  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  102-2018  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  103-2018  Ordinaria
#
#   FECHA INGRESO FECHA TERMINO  DURACION CAUSA MOTIVO TERMINO
# 0    2018-04-02    2018-06-01              60      SENTENCIA
# 1    2018-04-02    2018-08-29             149      SENTENCIA
# 2    2018-01-10    2018-03-14              63      SENTENCIA
# 3    2018-04-02    2018-05-29              57      SENTENCIA
# 4    2018-04-02    2018-05-30              58      SENTENCIA

# %% [markdown]
# # DATA INVENTARIO

# %%
df_inventario = pd.read_feather("FEATHER_FILES/Inventario_feather")
df_inventario.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                     TRIBUNAL       RIT COMPETENCIA TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  123-2016        ORAL  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  159-2019        ORAL  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  160-2019        ORAL  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  176-2019        ORAL  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  196-2013        ORAL  Ordinaria
#
#    COD. MATERIA                                            MATERIA  \
# 0           856                   APROPIACION INDEBIDA ART.470 N°1
# 1          7037           TRAFICO DE PEQUEÑA  CANTIDADE  (ART. 4).
# 2         10011   POSESION TENENCIA O PORTE DE MUN Y SUST QUIMICAS
# 3         12051  CONTRAB. INFRAC A LA ORD. DE ADUAN ART 168. LE...
# 4          7007                TRAFICO ILICITO DE DROGA  (ART. 3).
#
#   TIPO ULT. DILIGENCIA FECHA ULT. DILIGENCIA FECHA INGRESO
# 0            AUDIENCIA            2019-10-31    2016-04-29
# 1           RESOLUCION            2019-12-31    2019-05-28
# 2           RESOLUCION            2019-11-21    2019-05-28
# 3           RESOLUCION            2019-12-31    2019-06-06
# 4           RESOLUCION            2019-09-10    2013-08-05

# %%
codigos_delitos = df_inventario['COD. MATERIA'].unique()

# %%
len(codigos_delitos)
# Out:
# 458

# %%
codigos_no_encontrados = []
for delito in codigos_delitos:
    if not delito in codigos_cot:
        codigos_no_encontrados.append(delito)
        
codigos_no_encontrados
# Out:
# [13001, -31075, 4014, 4013, 4010, 4011, 0]

# %%
codigos_sin_registro = df_inventario[df_inventario['COD. MATERIA'].isin(codigos_no_encontrados)]

codigos_sin_registro['MATERIA'].unique()
# Out:
# array(['LE IONE  LEVE .', 'FALTAS AL REGIMEN PENITENCIARIO',
#        'E TAFA (SOLO CRIMEN)', 'LESIONES LEVES.', 'ESTAFA (SOLO CRIMEN)',
#        'ABUSO SEXUAL (SOLO CRIMEN)', 'VIOLACION (SOLO CRIMEN)',
#        'MANEJO EN ESTADO DE EBRIEDAD (SOLO CRIMEN)',
#        'TRAFICO ILICITO DE DROGAS (ART. 3).',
#        'DESACATO (ART. 240 CODIGO DE PROCEDIMIENTO CIVIL).',
#        'HURTO SIMPLE POR UN VALOR DE MEDIA A MENOS DE 4 UTM.',
#        'ESTAFAS Y OTRAS DEFRAUDACIONES CONTRA PARTICULARES',
#        'TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).',
#        'PORTE ILEGAL DE ARMA DE FUEGO, MUNICIONES Y OTROS SUJETAS A.',
#        'ROBO EN LUGAR HABITADO O DESTINADO A LA HABITACION.',
#        'CONSUMO/PORTE EN LUG.PUB.O PRIV.C/PREVIO CONCIERTO(ART.50).',
#        'CONDUC. ESTADO DE EBRIEDAD CON O SIN DAÑOS O LESIONES LEVES',
#        'HOMICIDIO.',
#        'FALSIFICACION LICENCIA DE CONDUCIR Y OTRAS FALSIFICACIONES.',
#        'DAÑOS O APROPIACION SOBRE MONUMENTOS NACIONALES.',
#        'POSESION, TENENCIA O PORTE DE ARMAS SUJETAS A CONTROL',
#        'CONDUCCION EBRIEDAD RESUL.MUERTE  ART.196 INC.3LEY.TRANSITO.',
#        'ROBO POR SORPRESA.',
#        'ROBO EN BIENES NACIONALES DE USO PUBLICO O SITIOSNO DESTIN.',
#        'AMENAZAS SIMPLES CONTRA PERSONAS Y PROPIEDADES ART. 296 Nº3.',
#        'LESIONES MENOS GRAVES.', 'ROBO CON INTIMIDACION.',
#        'RECEPTACION. ART. 456 BIS A.', 'ROBO CON VIOLENCIA.',
#        'ABUSO SEXUAL DE MENOR DE 14 AÑOS (CON CONTACTO CORPORAL).',
#        'MALTRATO OBRA A CARABINEROS ART. 416 BIS CODIGO JUST.MILITAR',
#        'LESIONES GRAVES.', 'VIOLACION DE MAYOR DE 14 AÑOS.',
#        'CUASIDELITO DE HOMICIDIO.',
#        'FALSOTESTIMONIO, PERJURIO O DENUNCIA CALUMNIOSA.ART. 206,.',
#        'CONDUC. BAJO INFLUEN DEL ALCOHOL CON O SIN DAÑOS O LES.LEVES',
#        'LESIONES LEVES 494 N°5 CODIGO PENAL',
#        'CONSUMO/PORTE DE DROGAS EN LUGARES CALIFICADOS (ART. 51).',
#        'HURTO FALTA (494 BIS CODIGO PENAL).',
#        'RIÑA PUBLICA (496 Nº 10 CODIGO PENAL).',
#        'APROPIACION INDEBIDA ART.470 N°1',
#        'VENTA ILICITA DE OBRAS PROTEGIDAS POR LEY DE PROPIEDAD INTEL',
#        'INFRACCION ARTICULO 454 C.PENAL.', 'DAÑOS SIMPLES.',
#        'AMENAZA CON ARMA (FALTA) ART. 494 Nº 4 CODIGO PENAL.',
#        'OTROS DELITOS CONTRA LA LEY DE PROPIEDAD INTELECTUAL.',
#        'ROBO CON VIOLACION.',
#        'ARROJAMIENTO DE PIEDRAS U OTROS OBJETOS (496 NR26 CODIGO PEN',
#        'LESIONES GRAVES GRAVISIMAS. ART. 397 Nº 1.',
#        'OCULTACION DE IDENTIDAD (496 NR 5 CODIGO PENAL).',
#        'DELITO DESORDENES PUBLICOS ART. 269 (NO FALTA DEL CODIGO 130',
#        'FRAUDES AL FISCO Y ORGANISMOS DEL ESTADO (ART. 239).',
#        'HURTO SIMPLE POR UN VALOR DE 4 A 40 UTM.',
#        'PORTE DE ARMA CORTANTE O PUNZANTE (288 BIS).',
#        'OTROS DELIT COMET. POR EMP. PUBLIC.EN EL DESEM DE SUS CARGOS',
#        'VIOLACION  DE MORADA.',
#        'INJURIAS Y CALUMNIAS POR MEDIOS DE COMUNICACION SOCIAL.',
#        'OTROS DELITOS CONTRA LA LEY DEL TRANSITO.',
#        'OTROS DELITOS CONTRA LEY DE PROPIEDAD INDUSTRIAL.',
#        'ROBO CON FUERZA DE CAJEROS AUTOMATICOS',
#        'ABUSO SEXUAL DE MAYOR DE 14 (CON CIRCUNSTANCIAS DE VIOLACION',
#        'INFRACCION ORDENANZA ADUANAS (FRAUDE Y CONTRABANDO).',
#        'APROPIACION INDEBIDA (INCLUYE DEPOSITARIO ALZADO).',
#        'DEJAR ANIMALES SUELTOS (496 NR 17 CODIGO PENAL).',
#        'FALTA DE RESPETO A AUTORIDAD PUBLICA (495 Nº 4 CODIGO PENAL)',
#        'USO FRAUDULENTO DE TARJETAS DE CREDITO Y DEBITO.',
#        'CUASIDELITO DE LESIONES: ART 490, 491 INC 2° Y 492.',
#        'MALTRATO HABITUAL(VIOLENCIA INTRAFAMILIAR) (ART. 14).',
#        'CUASIDELITO DE LESIONES COMETIDOS POR PROFESIONALES DE LA SA',
#        'HURTO SIMPLE POR UN VALOR SOBRE 40 UTM.',
#        'OTRAS FALTAS CODIGO PENAL.',
#        'MALTRATO DE OBRA PERSONAL INVESTIGACIONES CON O SIN LESIONES',
#        'USURPACION DE NOMBRE.', 'DELITOS MARCARIOS.',
#        'ACCIDENTE CON RESULTADO DE MUERTE O LESIONES GRAVES. LEY DE.',
#        'GIRO DOLOSO DE CHEQUES (SOLO CRIMEN)',
#        'PROM. O FACIL. ENTR. O SAL DE PERSO DEL PAIS PARA PROSTITUCI',
#        'AMENAZASA CARABINEROS (ART. 417 COD. J.MILITAR).',
#        'AMENAZA A GENDARME EN EL DESEMPEÑO DE SUS FUNCIONES.',
#        'DAÑO FALTA (495 NR 21 CODIGO PENAL).',
#        'ASOCIAC. ILICITA PARA TRAFICO DE PERSONAS ART.411',
#        'FALSIFICACION O USO MALICIOSOS DE DOCUMENTOS PUBLICOS.',
#        'CONDUCCION SIN LA LICENCIA DEBIDA ART 194 LEY DE TRANSITO.',
#        'AMENAZAR SIMPLE O CONDICIONAL. ,OFENDER PERS.INVESTIGACIONES',
#        'INJURIA (ACCION PRIVADA).',
#        'FALSIFICACION DE OBRAS PROTEGIDAS POR LEY DE PROPIEDAD INTEL',
#        'VIOLENCIA EN LOS ESTADIOS (ART. 6 LEY 19.327).',
#        'HOMICIDIO CALIFICADO.',
#        'OTROS HECHOS QUE NO CONSTITUYAN DELITO: AGRUP.1008,1009,1011',
#        'TRATA DE PERSONAS PARA LA EXPLOTACION SEXUAL',
#        'AMENAZAS DE ATENTADOS CONTRA PERSONAS Y PROPIEDADES.',
#        'ABUSO SEXUAL CALIFICADO C/INTRODUCCION OBJETOS O USO ANIMAL.',
#        'CONDUCCION EBRIEDAD SUSP.LIC. ART.196Y209 INC.2 LEY.TRANSITO',
#        'PRESUNTA DESGRACIA.',
#        'FALSIFICACION O USO MALICIOSO DE DOCUMENTOS PRIVADOS.',
#        'VIOLACION DE MENOR DE 14 AÑOS.',
#        'CUASIDELITO DE HOMICIDIO COMETIDO POR PROFESIONALES DE LA SA',
#        'HURTO AGRAVADO (ART. 447 CODIGO PENAL).',
#        'PORTE DE ARMA PROHIBIDA (ART. 14 INC. 1°)',
#        'PRESENTACION DE PERITOS,TESTIGOS O INTERPRETES QUE FALTAREN.',
#        'ABORTO CONSENTIDO.',
#        'ATENTADO A VEHICULO MOTORIZADO EN CIRCULACION CON OBJETO CON',
#        'ABANDONO DE CONYUGE O DEPARIENTES ENFERMOS.',
#        'PREVARICACION DEL ABOGADO Y PROCURADORARTS. 231 Y 232.',
#        'POSESION O TENENCIA DE ARMAS PROHIBIDAS',
#        'ROBO EN LUGAR NO HABITADO.', 'INCENDIO',
#        'DELITOS QUE CONTEMPLA EL CODIGO TRIBUTARIO.',
#        'OFENSAS AL PUDOR (495 NR 5 CODIGO PENAL).',
#        'INFRACCION AL ART. 9 DEL DECRETO LEY 2.695.',
#        'OTRAS INFRACCIONES LEY 18.892  DE PESCA',
#        'USURPACION NO VIOLENTA (ART. 458 CODIGO PENAL).',
#        'OTROS DELITOS DE LA LEY 20.000.',
#        'OBTENCION DE SERVICIOS SEXUALES DE MENORES.',
#        'FEMICIDIO ART.390 INC.2',
#        'TRAFICO DE MIGRANTES  411 BIS INCISO 1, 2 Y 3',
#        'OTROS DELITOS DE LA LEY DE CONTROL DE ARMAS (LEY 17.798)',
#        'ESTUPRO.',
#        'CONDUC VEHIC DURANTE VIG ALG. SANCI IMPUEST ART209 LEY 18290',
#        'INFRACCION LEY 18.892 DE PESCA.',
#        'PROMOVER O FACILITAR PROSTITUCION DE MENORES.',
#        'ROBO CON HOMICIDIO.',
#        'ABUSO SEXUAL DE 14 AÑOS A MENOR DE 18 AÑOS CON CIRCUNSTANCIA',
#        'CONDUC. EBRIEDAD RESUL.LESIONES GRAVE.ART 196 INC.2LEY.TRANS',
#        'MALTRATO DE OBRA A GENDARME EN EL DESEMPEÑO DE SUS FUNCIONES',
#        'PREVARICACION JUDICIAL Y ADMINISTRATIVA ART. 223 AL 229.',
#        'DELITOS CONTRA LEY DE PROPIEDAD INTELECTUAL.',
#        'MALVERSACION DE CAUDALES PUBLICOS.',
#        'OTROS DELITOS CONTRA LAS PERSONAS',
#        'ABUSO SEXUAL IMPROPIO MAYOR DE  14 AÑOS Y MENOR 18 AÑOS',
#        'HURTO DE HALLAZGO.',
#        'AMENAZAS CONDIC.C/PERSONAS Y PROPIEDADES ART.296 1Y2,ART.297',
#        'NEGOCIACION INCOMPATIBLE.', 'MALTRATO ANIMAL.',
#        'USURPACION DE PROPIEDAD,DESCUBRIMIENTO O PRODUCCION.ART.158.',
#        'CONDUCCION ESTADO DE EBRIEDAD CON RESULTADO DE DAÑOS.ART. 19',
#        'INFRACCION LEY GRAL DE TELECOMUNICACIONES ART. 36 B',
#        'CONDUC.ESTADO EBRIEDAD C/RESULT.MUERTE O LESION GRAVES GRAV.',
#        'SOBORNO.ART. 250. PERSONA  NATURAL',
#        'CELEBRACION DE CONTRATO SIMULADO.',
#        'OTRAS INFRACCIONES AL CSDIGO DE JUSTICIA MILITAR.',
#        'OBSTRUCCION A LA INVESTIGACION.',
#        'NO DAR CUENTA DE ACCIDENTE DE TRANSITOART. 195LEY DE TRA.',
#        'DELITOS CONTEMPLADOS EN OTROS TEXTOS LEGALES.',
#        'HALLAZGO DE DROGAS.',
#        'CAZA Y COMERCIALIZACION DE ESPECIES PROHIBIDAS (ART. 31 LEY.',
#        'FALSIFICACION DE MONEDA Y OTROS (ART. 162 CODIGO PENAL).',
#        'ATENTADO CONTRA JEFE DE ESTADO O AUTORIDAD PUBLICA.',
#        'DEPOSITARIO ALZADO ART. 444 CPC',
#        'ROBO O HURTO DE MATERIAL DE GUERRA',
#        'MUERTES Y HALLAZGO DE CADAVER.', 'ABIGEATO.',
#        'CONDUCCION BAJO LA INFLUENCIA DEL ALCOHOL CAUSANDO LESIONES.',
#        'ATENTADOS Y AMENAZAS CONTRA LA AUTORIDAD. ART. 261Nº 1Y.',
#        'USURPACION VIOLENTA.', 'COHECHO.', 'OTROS ESTRAGOS.',
#        'ESPIONAJE INFORMATICO ART. 2 Y 4 LEY 19223.',
#        'FALSIFICACION PLACAS,TARJETAS,TIMBRES Y SELLOS DE INVESTIGAC',
#        'CONDUC.EBRIEDAD RESUL.LESIONES MENOS GRAVE.A196 I.2LEY.TRANS',
#        'RUIDOS MOLESTOS (495 NR 1 CODIGO PENAL).',
#        'PRESUNTA DESGRACIA INFANTIL.', 'COMERCIO CLANDESTINO\xa0.',
#        'ASOCIACIONES ILICITAS LEY DE DROGAS (ART. 16).',
#        'ABANDONO DE NIQOS.', 'ABUSO SEXUAL IMPROPIO MENOR DE 14 AÑOS',
#        'EXTORSION.',
#        'PRODUCCION MATERIAL PORNOGRAFICO UTILIZANDO MENORES 18 AÑOS.',
#        'DAÑOS CALIFICADOS.', 'ULTRAJE PUBLICO A LAS BUENAS COSTUMBRES.',
#        'DELITOS CONTRA LA VIDA Y LA PRIVACIDAD DE LAS CONVERSACIONES',
#        'CULTIVO/COSECHA ESPEC.VEGETALES PRODUCTORAS ESTUPEF.(ART.8.',
#        'CONDUC.ESTADO EBRIEDAD C/RESULT.LESIONES GRAVES O MENOS GRA.',
#        'ABUSOS CONTRA PARTICULARES.ART. 255.',
#        'INCENDIO DE BOSQUES (ART. 476).',
#        'CUASIDELITO VEHICULO MOTORIZADO LEY TRANSITO',
#        'LAVADO DE DINERO PERSONA JURIDICA ART. 27  LEY 19.913',
#        'FALSIFICACION DE BILLETES ART. 64 LEY ORGANICA BANCO CENTRAL',
#        'INFRACCION A LA LEY ELECTORAL.',
#        'LAVADO DE DINERO PERSONA NATURAL ART. 27  LEY 19.913',
#        'INCENDIO CON PELIGRO PARA LAS PERSONAS: ART 475 Y ART. 476',
#        'CALUMNIA (ACCION PRIVADA).',
#        'PORTAR ELEMENTO CONOCIDAMENTE DESTINADOS COMETER DELITO ROBO',
#        'ROBO DE VEHICULO MOTORIZADO.', 'QUEBRANTAMIENTO.',
#        'DECLARAC. MALICIOSA IMPUESTO ART.97 Nº4.EXCEPT INC.3 C.TRIB',
#        'ROTURA DE SELLOS.',
#        'UTILIZACION SIN AUTORIZACION DE OBRAS DE DOMINIO AJENO POR L',
#        'EXPENDIO DE BEBIDAS ALCOHOLICAS A MENORES.',
#        'ADQUISICION O ALMACENAMIENTO MATERIAL PORNOGRAFICO INFANTIL.',
#        'DISENSIONES DOMESTICAS (495 NR 6 CODIGO PENAL).',
#        'EXTRANJEROS QUE INGRESAN O INTENTAN EGRESAR CLANDESTINAMENTE',
#        'APROPIACION DE COTIZAC.PREVISIONALES Y DECLARACION INEXACTAS',
#        'INCENDIO SOLO C/DAÑOS O SIN PELIGRO PROPAGACION.ART.477,478.',
#        'PRODUC Y TRAFICO POR DESVIO DE PRECURSORES ART. 2 LEY 20.000',
#        'USURA.', 'EJERCICIO ILEGAL DE LA PROFESION.ART. 213. INC. 1º.',
#        'EXTRANJE. INGRESAN O INTENTAN EGRESAR C/DOCUMENTOS FALSIFIC.',
#        'OPONERSE A LA ACCION DE LA AUTORIDAD PUBLICA O SUS AGENTES.',
#        'DESORDENES EN ESPECTACULOS PUBLICOS (494 Nº 1 CODIGO PENAL).',
#        'SABOTAJE INFORMATICO.', 'ABANDONO DE DESTINO.',
#        'INFRACCIONES TRIBUTARIAS CONTEMPLADAS EN OTRAS LEYES.',
#        'ASOCIACION ILICITA ART. 28  LEY 19.913', 'USURPACION DE AGUAS.',
#        'VIOLACION DE SECRETOS.',
#        'OTROS DELIT CONTRA ORDEN DE FLIAS, MORA. PUB. INTEGR. SEXUAL',
#        'PARRICIDIO.', 'HALLAZGO DE VEHICULO.',
#        'ROBO CON RETENCION DE VICTIMAS O CON LESIONES GRAVES.',
#        'SODOMIA. ART. 365.', 'SUSTRACCION DE MENORES.',
#        'NEGATIVA A EFECTUARSE EXAMEN. ART. 195 LEY  DE TRANSITO',
#        'OTROS DELIT CONTRA LA FE PUB, FALSIFIC., FALSO TESTIM Y PERJ',
#        'USURPACION DE ATRIBUCIONES DE EMPLEADOS PUBLICOS Y JUDICIALE',
#        'TORMENTOS Y APREMIOS COMETIDOS POR EMPLEADOS PUBLICOS 150 A',
#        'OBTENCION INDEBIDA DEVOL.IMPUESTO.ART 97 N.4.INC.3.COD.TRIBU',
#        'OTROS DELITOS LEY GENERAL DE BANCOS.',
#        'OTROS DELITOS CONTRA LA PROPIEDAD', 'OTROS DE LOS CUASIDELITOS',
#        'HURTO DE BIENES PERTENECIENTES A REDES DE SUMINISTRO PUBLICO',
#        'FRAUDE DE SUBVENCIONES ART 470 N°8',
#        'OTROS DELIT QUE AFECTAN LOS DCHOS GARANT. POR LA CONSTITUC',
#        'ALLANAMIENTOS IRREGULARES.',
#        'DETENCION, DESTIERRO O ARRESTO IRREGULAR ART. 148',
#        'COMERCIALIZAR,DISTRIBUIR, INSTALAR MAQUINAS JUEGOS ILEGALES.',
#        'TRAFICO DE INFLUENCIAS.',
#        'CONDUC. EBRIEDAD RESUL.LESIONES GRAVE.ART.196 INC.3LEY.TRANS',
#        'ABUSO DE FIRMA EN BLANCO.', 'VIOLACION CON HOMICIDIO.',
#        'ATENTADO EXPLOSIVO O INCENDIARIO. ART. 2 Nº 4 LEY 18.314.',
#        'HURTO SIMPLE.',
#        'DELITOS CONTENIDOS EN EL D.L. 1094 DE EXTRANJERIA.',
#        'ASOCIACIONES ILICITAS.', 'ABUSO SEXUAL ADULTO',
#        'HOMICIDIO EN RIÑA O PELEA.', 'CONSUMO DE DROGAS (ART. 41).',
#        'ABUSOS CONTRA PARTICULARES.',
#        'DELITOS CONTENIDOS EN LA LEY 19.620 DE ADOPCISN DE MENORES.',
#        'VIOLACION',
#        'CONNIVENCIA EN LA FUGA Y EVASION CULPABLE DE DETENIDOS',
#        'INFRACCIONES A LA LEY ORGANICA CONSTITUCIONAL SOBRE VOTACION',
#        'TRAFICO DE ORGANOS (ART. 13 LEY 19.451 SOBRE TRANSPLANTE Y D',
#        'OTORGAMIENTO IRREGULAR DE DOCUMENTOS ART. 190 LEY DE TRANSIT',
#        'SECUESTRO.', 'OBTENCION FRAUDULENTA DE CREDITOS.',
#        'CONTRA SALUD PUBLICA.',
#        'FALSIFICA DE LICENCIAS MEDICAS O PENSION ART.202 INC.2° Y 3°',
#        'FALSA ALARMA DE INCENDIO, EMERGENCIA O CALAMIDAD PUBLICA',
#        'INFRACCION EN EL OTORGAMIENTO PRESTACIONES DE ISAPRE (ART.23',
#        'INDUCIR A UN MENOR A ABANDONAR EL HOGAR.',
#        'ULTRAJE PUBLICO BUENAS COSTUMBRES POR MEDIO COMUNIC. SOCIAL.',
#        'DELITOS CONTRA LEY DE PROPIEDAD INDUSTRIAL.',
#        'AUXILIO AL SUICIDIO.',
#        'ABANDONO DE ARMAS O ELEMENTOS SUJETAS A CONTROL. ART. 14 A.',
#        'FALSEDADES ART. 367 AL 371 CODIGO JUSTICIA MILITAR',
#        'INJURIA A TRAVES DE MEDIOS DE DIFUSION (ACCION PRIVADA).',
#        'LOTERIA ILEGAL, CASAS DE JUEGO Y PRESTAM  SOBRE PRENDA',
#        'OTRAS FALTAS LEYES ESPECIALES',
#        'OTROS DELITOS L.O.C. DE INVESTIGACIONES.',
#        'INFRACCION NORMAS INHUMACIONES Y EXHUMACIONES.',
#        'OTROS DELITOS LEY DE CUENTAS CORRIENTES BANCARIAS Y CHEQUE.',
#        'SOBORNO.ART. 250. PERSONA  JURIDICA',
#        'ABORTO COMETIDO POR FACULTATIVO.',
#        'MATAR CARABINERO EN EJERCICIO DE FUNCIONES, JUSTICIA MILITAR',
#        'ABORTO SIN CONSENTIMIENTO.',
#        'OTRAS INFRACCIONES A LA LEY DEL BANCO CENTRAL.',
#        'CASTRACION Y MUTILACION.', 'USURPACION DE ESTADO CIVIL.',
#        'INFRACCION  POR CONTAMINACION ART.136 LEY  18.892  DE PESCA',
#        'FABRICACION, ACOPIO O COMERCIALIZACION DE HILO CURADO.',
#        'DESTRUCCION O ALTERACION DE DESLINDES.',
#        'CONSUMO Y OTRAS FALTAS LEY DE DROGAS.',
#        'TORMENTOS Y APREMIOS COMETIDOS POR PARTICULARES 150 B',
#        'CONTRA SALUD PUBLICA. ARTS. 313 A Y 313 B', 'INFANTICIDIO.',
#        'USO ILICITO FUEGO ART.18, 22, Y 22 TER DS4363 LEY DE BOSQUES',
#        'PROPAG. DE ENFERMED  QUE AFECTEN LA SALUD ANIMAL O VEGETAL',
#        'INFRACCION A LEY 11.564 DE MATADEROS CLANDESTINOS.',
#        'OTRAS FALTAS Y DELITOS DE LA LEY 19.733.',
#        'LOTEOS IRREGULARES (ART. 138 DFL 458, 1975, LEY GENERAL DE U',
#        'INTERRUPCION DE SERV. ELECTRICO (ART. 134 DFL 1, 1982, LEY.',
#        'MALTRATO OBRA A FISCALES O DEFENSORES EN DESEMPEÑO FUNCIONES',
#        'DELITOS CONTRA LA LEY DE BOSQUE NATIVO.LEY 20.283.',
#        'OTROS ABUSOS CONTRA PARTICULARES.ART. 256,257,258,259.',
#        'INCENDIO CON RESULTADO DE MUERTE Y/O LESIONES.',
#        'OTROS DELIT. CONTRA ORDEN Y SEG. PUBLIC COMET POR PARTICUL',
#        'SECUESTRO CON HOMICIDIO, VIOLACION O LESIONES.',
#        'APROPIACION DE CABLES TENDIDO ELECTRICO O DE COMUNICACIONES.',
#        'USO,FACILITACION O TRANSPORTE DE HILO CURADO.',
#        'TACHA FALSA DE FIRMA AUTENTICA.', 'NEGLIGENCIA MEDICA.',
#        'DELITOS CONTENIDOS EN LEYES DE PRENDA ESPECIALES LEY 20.190.',
#        'OBSTRUC.JUSTICIA P/FISCAL O ASIST.FISCAL,MINISTERIO PUBLICO.',
#        'AMENAZA A FISCALES O DEFENSORES EN EL DESEMPEÑO DE FUNCIONES',
#        'FINGIMIENTO DE CARGOS O PROFESIONES .ART. 213 INC. 2.',
#        'HOMICIDIO SIMPLE.', 'INFRACCION LEY 18.175 DE QUIEBRAS.',
#        'VIOLACION DE SECRETOS DE FABRICA.ART.284.',
#        'GANADO QUE ENTRA A PREDIO AJENO CAUSANDO DAÑOS',
#        'ROBO CON CASTRACION, MUTILACION O LESIONES GRAVES GRAVISIMAS',
#        'ADQUISICION Y VENTA INDEBIDA DE CARTUCHOS Y MUNICIONES. ART.',
#        'ENRIQUECIMIENTO ILICITO.', 'INFRACCIONES A LA SEGURIDAD SOCIAL.',
#        'CORTE/DESTR. ARBOL/ARBUSTO. REG.ART.21 4363,1931Y LEY BOSQUE',
#        'BIGAMIA.',
#        'OBSTRUCCION A LA JUSTICIA CON OCASION DE TRATAMIENTO DE ADN.',
#        'EJERCICIO IRREGULAR DE MARTILLERO PUBLICO (ART.23 LEY 18.118',
#        'LEY RESPONSABILIDAD PENAL PERSONAS JURIDICAS LEY 20393',
#        'NOMBRAMIENTOS ILEGALES.',
#        'TRATA PERS.MENORES DE 18 AÑOS. ART. 411 QUATER INC. 2',
#        'MALVERSACION,DEFRAUDACION E INCENDIO POR MENOS DE 1 UTM.',
#        'INCESTO.', 'OTROS LEY 18.314.',
#        'CRIMENES Y SIMPLES DELITOS SEGURIDAD INTERIOR DEL ESTADO.',
#        'INFRACCION L.O.C DEL BANCO CENTRAL.',
#        'USO DE UNIFORME O INSIGNIAS DE FF.AA. O CARABINEROS DE CHILE',
#        'INFRACCIONES AL COD. AERONAUTICO (ARTS. 190, 194 BIS, 195 A.',
#        'FALSIFICACION O USO DE PASAPORTES O PERMISOS PARA PORTE DE A',
#        'DELITOS RELATIVOS AL PAGO DE PENSIONES ALIMENTICIAS LEY 14.9',
#        'NO APLICA', 'TRAFICO DE ARMAS (ART. 10)',
#        'SOBORNO FUNC. PUBLICO EXTRANJERO,PERSONA NATURAL ART.251 BIS',
#        'APERTURA , REGISTRO O INTERCEPTACION DE CORRESPONDENCIA.',
#        'OTRAS INFRACCIONES A LA LEY 19.913.',
#        'ASOCIACISN ILICITA TERRORISTA.',
#        'VIGILANCIA PRIVADA NO AUTORIZADA (ART.5 BIS DECRETO LEY 3607',
#        'CRMMENES Y SIMPLES DELITOS C/SOBERANMA NAC. Y SEG DEL ESTADO',
#        'INSOLVENCIA PUNIBLE (ALZAMIENTO DE BIENES).',
#        'EXACCIONES ILEGALES COMETIDAS POR FUNCIONARIO PUBLICO.',
#        'INFIDELIDAD EN LA CUSTODIA DE DOCUMENTOS.', 'DAÑOS.',
#        'CRIMENES LESA HUMANIDAD Y GENOCIDIO LEY 20.357.',
#        'INFRACCION A LA LEY MERCADO DE VALORES (ARTS. 59 Y 60 LEY ).',
#        'CONDUCCION BAJO LA INFLUENCIA DEL ALCOHOL',
#        'TRANSPORTE O DISTRIBUCION DE GAS E INSTALACION CLANDESTINAS.',
#        'RECAUD./PROVEER FONDO COMIS.DEL.TERROR.PERS.NAT.ART8LEY18134',
#        'ABUSOS DESHONESTOS.',
#        'FALTAS CODIGO PENAL CONOCIDAS POR JUZGADOS DEL CRIMEN.',
#        'ELABORACION ILEGAL DE DROGAS O SUSTANCIAS SICOTROPICAS ART.',
#        'ROBO CON FUERZA EN LAS COSAS.',
#        'OTORGAMIENTO DE PATENTES DE ALCOHOLES.',
#        'TRATA PERS.PARA TRABAJOS FORZADOS Y OTROS A.411 QUAT.INC.1',
#        'ALTERACION FRAUDULENTA DE PRECIOS.',
#        'SUMINISTRO INDEBIDO DE DROGAS ART. 7 LEY Nº 20.000.',
#        'APODERAMIENTO O ATENTADO AL TRANSPORTE PUBLICO.',
#        'SOBORNO FUNC.PUBLICO EXTRANJERO.PERSONA JUR. ART. 251 BIS',
#        'ENVIO EXPLOSIVOS,HOMICIDIO,LESIONES Y SECUESTRO TERRORISTA.',
#        'FRAUDES AL FISCO Y ORGANISMOS DEL ESTADO (ART. 239)',
#        'DIRIGIR REUNIONES TUMULTUOSAS ART 494 Nº 2 CODIGO PENAL.',
#        'CONTRA SALUD PUBLICA. ARTS. 313 D AL 318.',
#        'DELITOS INFORMATICOS LEY N: 19.223.',
#        'EXACCIONES ILEGALES COMETIDAS POR PARTICULARES.',
#        'HOMICIDIO DE FISCALES O DEFENSORES EN DESEMPEÑO DE FUNCIONES',
#        'PRESCRIP.MEDICA ABUSIVA DROGAS ESTUPEF.O SICOTROP.(ART.6).',
#        'HOMICIDIO DE GENDARME EN EL DESEMPEÑO DE SUS FUNCIONES.',
#        'ABORTO.', 'TOLERANCIA AL TRAFICO O CONSUMO DE DROGAS ART. 12.',
#        'LEY N: 18,314 DE CONDUCTAS TERRORISTAS.',
#        'FRAUDULENTA ATRIBUCION CALIDAD DE INDIGENA ART.5 LEY 19.253.',
#        'TRATA DE PERSONAS.',
#        'INVASION DE DERECHOS AJENOS (ART. 459 CODIGO PENAL).',
#        'LAVADO DE DINERO.'], dtype=object)

# %% [markdown]
# # DATA AUDIENCIAS

# %%
df_audiencias = pd.read_feather("FEATHER_FILES/Audiencias_feather")
df_audiencias.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                        TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  101-2018  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  101-2018  Ordinaria
#
#                                    TIPO DE AUDIENCIA  \
# 0                       AUDIENCIA DE JUICIO ORAL TOP
# 1                 AUDIENCIA DE LECTURA DE SENTENCIA.
# 2                   AUDIENCIA DE MEDIDAS CAUTELARES.
# 3               AUDIENCIA DE COMPARECENCIA JUDICIAL.
# 4  AUDIENCIA PRESENTACION VOL.IMPUTADO C/ORD. DETEN.
#
#   FECHA PROGRAMACION AUDIENCIA FECHA AUDIENCIA  DIAS AGENDAMIENTO  \
# 0                   2018-04-03      2018-05-28                 55
# 1                   2018-06-01      2018-06-01                  0
# 2                   2018-06-19      2018-06-23                  4
# 3                   2018-04-03      2018-05-23                 50
# 4                   2018-05-24      2018-05-24                  0
#
#   DURACION AUDIENCIA (MIN)
# 0                      164
# 1                        9
# 2                        4
# 3                        3
# 4                        3

# %% [markdown]
# # DATA DURACION

# %%
df_duracion = pd.read_feather("FEATHER_FILES/Duraciones_feather")
df_duracion.head()
# Out:
#    index  COD. CORTE                           CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA                             988
# 1      1          10  C.A. DE ARICA                             988
# 2      2          10  C.A. DE ARICA                             988
# 3      3          10  C.A. DE ARICA                             988
# 4      4          10  C.A. DE ARICA                             988
#
#                                        TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2019  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  101-2019  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA   10-2019  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  102-2019  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  103-2019  Ordinaria
#
#   FECHA INGRESO FECHA TERMINO DURACIÓN CAUSA  \
# 0    2019-04-03    2019-05-17             44
# 1    2019-04-04    2019-05-17             43
# 2    2019-01-04    2019-01-29             25
# 3    2019-04-04    2019-11-20            230
# 4    2019-04-05    2019-04-10              5
#
#                        MOTIVO TERMINO
# 0                           SENTENCIA
# 1                           SENTENCIA
# 2                           SENTENCIA
# 3                           SENTENCIA
# 4  DECLARA SOBRESEIMIENTO DEFINITIVO.

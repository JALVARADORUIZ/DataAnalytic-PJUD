# %% [markdown]
# # Generación de Data Única referente a Materia
#
# Unificacion de la data de ingresos y terminos por Materia penal, además de transformación de algunos datos para normalizar nombres en columnas

# %%
import pandas as pd
import numpy as np
import os

from tqdm import tqdm
from unicodedata import normalize

from pjud.data import cleandata
from pjud.data import transformdata

# %%
tqdm.pandas()

path_interim = "../data/interim/pjud"
path_processed = "../data/processed/pjud"
# Out:
# /Users/jalvaradoruiz/opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# # DATA de TRIBUNALES OBTENIDAS DEL COT

# %%
# Analizo contra los datos extraidos en COT
df_tribunales = pd.read_feather(f"{path_processed}/generates_ListadoTribunales.feather")
tribunales = df_tribunales['TRIBUNAL'].unique()

# %% [markdown]
# # DATAS INGRESO Y TERMINO MATERIA

# %% [markdown]
# ### DATA INGRESO X MATERA

# %%
df_ingresos_materia = pd.read_feather(f"{path_interim}/clean_IngresosMateria.feather")
df_ingresos_materia.head()
# Out:
#    index  COD. CORTE          CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA            988
# 1      1          10  C.A. DE ARICA            988
# 2      2          10  C.A. DE ARICA            988
# 3      3          10  C.A. DE ARICA            988
# 4      4          10  C.A. DE ARICA            988
#
#                                        TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  101-2018  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA   10-2018  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  102-2018  Ordinaria
#
#    COD. MATERIA                                            MATERIA  \
# 0          7007                TRAFICO ILICITO DE DROGAS (ART. 3).
# 1         10004  PORTE ILEGAL DE ARMA DE FUEGO, MUNICIONES Y OT...
# 2         12149  DESACATO (ART. 240 CODIGO DE PROCEDIMIENTO CIV...
# 3          7037           TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).
# 4           812                       RECEPTACION. ART. 456 BIS A.
#
#   FECHA INGRESO MES INGRESO  AÑO INGRESO  TOTAL INGRESOS POR MATERIAS
# 0    2018-04-02      abr-18         2018                            1
# 1    2018-04-02      abr-18         2018                            1
# 2    2018-04-02      abr-18         2018                            1
# 3    2018-01-10      ene-18         2018                            1
# 4    2018-04-02      abr-18         2018                            1

# %%
# Normalizo nombres

df_ingresos_materia['TRIBUNAL'] = df_ingresos_materia['TRIBUNAL'].progress_apply(cleandata.cambio_nombre_juzgados)
# Out:
# 100%|██████████| 3210689/3210689 [00:18<00:00, 173264.62it/s]

# %%
# Verifico si coinciden los nombres e imprimo los que estan en conflicto

for tribunal in df_ingresos_materia['TRIBUNAL'].unique():
    if not tribunal in tribunales:
        print(tribunal)

# %% [markdown]
# ### TERMINO X MATERIA

# %%
df_termino_materia = pd.read_feather(f"{path_interim}/clean_TerminosMateria.feather")
df_termino_materia.head()
# Out:
#    index  COD. CORTE          CORTE  COD. TRIBUNAL  \
# 0      0          10  C.A. DE ARICA            988
# 1      1          10  C.A. DE ARICA            988
# 2      2          10  C.A. DE ARICA            988
# 3      3          10  C.A. DE ARICA            988
# 4      4          10  C.A. DE ARICA            988
#
#                                        TRIBUNAL       RIT TIPO CAUSA  \
# 0  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 1  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  100-2018  Ordinaria
# 2  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  101-2018  Ordinaria
# 3  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA   10-2018  Ordinaria
# 4  TRIBUNAL DE JUICIO ORAL EN LO PENAL DE ARICA  102-2018  Ordinaria
#
#    COD. MATERIA                                            MATERIA  \
# 0          7007                TRAFICO ILICITO DE DROGAS (ART. 3).
# 1         10004  PORTE ILEGAL DE ARMA DE FUEGO, MUNICIONES Y OT...
# 2         12149  DESACATO (ART. 240 CODIGO DE PROCEDIMIENTO CIV...
# 3          7037           TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).
# 4           812                       RECEPTACION. ART. 456 BIS A.
#
#   FECHA INGRESO FECHA TERMINO MES TERMINO  AÑO TERMINO MOTIVO TERMINO  \
# 0    2018-04-02    2018-06-01      jun-18         2018      SENTENCIA
# 1    2018-04-02    2018-06-01      jun-18         2018      SENTENCIA
# 2    2018-04-02    2018-08-29      ago-18         2018      SENTENCIA
# 3    2018-01-10    2018-03-14      mar-18         2018      SENTENCIA
# 4    2018-04-02    2018-05-29      may-18         2018      SENTENCIA
#
#    DURACION CAUSA  TOTAL TERMINOS
# 0              60               1
# 1              60               1
# 2             149               1
# 3              63               1
# 4              57               1

# %%
# Normalizo nombres

df_termino_materia['TRIBUNAL'] = df_termino_materia['TRIBUNAL'].progress_apply(cleandata.cambio_nombre_juzgados)
# Out:
# 100%|██████████| 3603377/3603377 [00:20<00:00, 171914.83it/s]

# %%
# Verifico si coinciden los nombres e imprimo los que estan en conflicto

for tribunal in df_termino_materia['TRIBUNAL'].unique():
    if not tribunal in tribunales:
        print(tribunal)

# %% [markdown]
# ## Data relacionada a Delitos

# %%
path = "../data/processed/delitos"
df_delitos = pd.read_feather(f"{path}/clean_Delitos.feather")
df_delitos.head()
# Out:
#    index  COD. MATERIA                                            MATERIA  \
# 0      0           101                           QUEBRANTAMIENTO. ART. 90
# 1      1           202                                SECUESTRO. ART. 141
# 2      2           203                   SUSTRACCION DE MENORES. ART. 142
# 3      3           204                       VIOLACION DE MORADA. ART.144
# 4      4           205   APERTURA , REGISTRO O INTERCEPTACION DE CORRE...
#
#                                    TIPOLOGIA MATERIA VIGENCIA MATERIA
# 0  LIBRO I  TITULO IV   QUEBRANTAMIENTO DE SENTEN...          VIGENTE
# 1  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE
# 2  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE
# 3  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE
# 4  LIBRO II  TITULO III  CRIMENES Y SIMPLES DELIT...          VIGENTE

# %%
codigos_cot = df_delitos['COD. MATERIA'].unique()
print(f"Existen {len(codigos_cot)} codigos de delitos")
# Out:
# Existen 541 codigos de delitos

# %% [markdown]
# ## Delitos en INGRESOS MATERIA

# %%
codigos_delitos = df_ingresos_materia['COD. MATERIA'].unique()

# %%
len(codigos_delitos)
# Out:
# 473

# %%
codigos_no_encontrados = []
for delito in codigos_delitos:
    if not delito in codigos_cot:
        codigos_no_encontrados.append(delito)

# %%
codigos_no_encontrados
# Out:
# [13001, -31075, 0, 4011, 4014, 4013, 4010]

# %%
codigos_sin_registro = df_ingresos_materia[df_ingresos_materia['COD. MATERIA'].isin(codigos_no_encontrados)]

codigos_sin_registro['MATERIA'].unique()

# Analizar caso a caso:
# Out:
# array(['LESIONES LEVES.', 'FALTAS AL REGIMEN PENITENCIARIO', '[NULL]',
#        'MANEJO EN ESTADO DE EBRIEDAD (SOLO CRIMEN)',
#        'ESTAFA (SOLO CRIMEN)', 'ABUSO SEXUAL (SOLO CRIMEN)',
#        'VIOLACION (SOLO CRIMEN)'], dtype=object)

# %% [markdown]
# #### Caso Codigo 13001 -> LESIONES LEVES
# Este codigo debe tratarse como 13036 identificado como: LESIONES LEVES 494 Nº 5 CÓDIGO PENAL

# %%
df_ingresos_materia['COD. MATERIA'] = df_ingresos_materia['COD. MATERIA'].replace(13001,13036)

# %% [markdown]
# #### Caso Codigo -31075

# %%
filtro_codigo_31075 = df_ingresos_materia[df_ingresos_materia['COD. MATERIA']==-31075]
filtro_codigo_31075
# Out:
#           index  COD. CORTE                 CORTE  COD. TRIBUNAL  \
# 855922   205398          35      C.A. DE RANCAGUA           1070
# 855923   205399          35      C.A. DE RANCAGUA           1070
# 855924   205400          35      C.A. DE RANCAGUA           1070
# 1065019  414572          56  C.A. DE PUERTO MONTT           1090
# 1065020  414573          56  C.A. DE PUERTO MONTT           1090
# 1065023  414576          56  C.A. DE PUERTO MONTT           1090
# 1065027  414580          56  C.A. DE PUERTO MONTT           1090
# 1160591  510265          90      C.A. DE SANTIAGO           1226
#
#                                      TRIBUNAL         RIT TIPO CAUSA  \
# 855922           JUZGADO DE GARANTIA RANCAGUA  14692-2019  Ordinaria
# 855923           JUZGADO DE GARANTIA RANCAGUA  14693-2019  Ordinaria
# 855924           JUZGADO DE GARANTIA RANCAGUA  14694-2019  Ordinaria
# 1065019      JUZGADO DE GARANTIA PUERTO MONTT  12196-2019  Ordinaria
# 1065020      JUZGADO DE GARANTIA PUERTO MONTT  12197-2019  Ordinaria
# 1065023      JUZGADO DE GARANTIA PUERTO MONTT  12200-2019  Ordinaria
# 1065027      JUZGADO DE GARANTIA PUERTO MONTT  12202-2019  Ordinaria
# 1160591  SEPTIMO JUZGADO DE GARANTIA SANTIAGO  13218-2019  Ordinaria
#
#          COD. MATERIA                          MATERIA FECHA INGRESO  \
# 855922         -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-26
# 855923         -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-26
# 855924         -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-26
# 1065019        -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-23
# 1065020        -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-23
# 1065023        -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-23
# 1065027        -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-12-23
# 1160591        -31075  FALTAS AL REGIMEN PENITENCIARIO    2019-07-31
#
#         MES INGRESO  AÑO INGRESO  TOTAL INGRESOS POR MATERIAS
# 855922       dic-19         2019                            1
# 855923       dic-19         2019                            1
# 855924       dic-19         2019                            1
# 1065019      dic-19         2019                            1
# 1065020      dic-19         2019                            1
# 1065023      dic-19         2019                            1
# 1065027      dic-19         2019                            1
# 1160591      jul-19         2019                            1

# %% [markdown]
# No corresponde a delito sino a sanción interna de gendarmeria, por lo que se eliminarán

# %%
df_ingresos_materia.drop(filtro_codigo_31075.index, axis = 0, inplace = True)

# %% [markdown]
# ### Caso Codigo 0

# %%
filtro_codigo_0 = df_ingresos_materia[df_ingresos_materia['COD. MATERIA']==0]
filtro_codigo_0
# Out:
#           index  COD. CORTE             CORTE  COD. TRIBUNAL  \
# 1131971  481619          90  C.A. DE SANTIAGO           1223
# 1137312  486960          90  C.A. DE SANTIAGO           1223
#
#                                     TRIBUNAL        RIT TIPO CAUSA  \
# 1131971  CUARTO JUZGADO DE GARANTIA SANTIAGO  1870-2019  Ordinaria
# 1137312  CUARTO JUZGADO DE GARANTIA SANTIAGO  6225-2019  Ordinaria
#
#          COD. MATERIA MATERIA FECHA INGRESO MES INGRESO  AÑO INGRESO  \
# 1131971             0  [NULL]    2019-03-04      mar-19         2019
# 1137312             0  [NULL]    2019-07-05      jul-19         2019
#
#          TOTAL INGRESOS POR MATERIAS
# 1131971                            1
# 1137312                            1

# %% [markdown]
# #### valores Null

# %%
df_ingresos_materia.drop(filtro_codigo_0.index, axis = 0, inplace = True)

# %% [markdown]
# ### Codigos 4011, 4014, 4013, 4010
# codigos No vigentes, mal cargados en sistemas

# %%
filtro_codigo_4011 = df_ingresos_materia[df_ingresos_materia['COD. MATERIA']==4011]
filtro_codigo_4014 = df_ingresos_materia[df_ingresos_materia['COD. MATERIA']==4014]
filtro_codigo_4013 = df_ingresos_materia[df_ingresos_materia['COD. MATERIA']==4013]
filtro_codigo_4010 = df_ingresos_materia[df_ingresos_materia['COD. MATERIA']==4010]

# %%
df_ingresos_materia.drop(filtro_codigo_4011.index, axis = 0, inplace = True)
df_ingresos_materia.drop(filtro_codigo_4014.index, axis = 0, inplace = True)
df_ingresos_materia.drop(filtro_codigo_4013.index, axis = 0, inplace = True)
df_ingresos_materia.drop(filtro_codigo_4010.index, axis = 0, inplace = True)

# %%
pd.to_datetime(df_ingresos_materia['FECHA INGRESO'])
# Out:
# 0         2018-04-02
# 1         2018-04-02
# 2         2018-04-02
# 3         2018-01-10
# 4         2018-04-02
#              ...
# 3210684   2015-12-17
# 3210685   2015-12-17
# 3210686   2015-12-24
# 3210687   2015-12-29
# 3210688   2015-12-29
# Name: FECHA INGRESO, Length: 3210643, dtype: datetime64[ns]

# %% [markdown]
# ## DELITOS EN TERMINO MATERIA

# %%
codigos_delitos = df_termino_materia['COD. MATERIA'].unique()

# %%
len(codigos_delitos)
# Out:
# 468

# %%
codigos_no_encontrados = []
for delito in codigos_delitos:
    if not delito in codigos_cot:
        codigos_no_encontrados.append(delito)

# %%
codigos_no_encontrados
# Out:
# [13001, 4014, 4013, 4011, -31075, 4010, 0, 4007]

# %%
codigos_sin_registro = df_termino_materia[df_termino_materia['COD. MATERIA'].isin(codigos_no_encontrados)]

codigos_sin_registro['MATERIA'].unique()

# Analizar caso a caso:
# Out:
# array(['LESIONES LEVES.', 'ESTAFA (SOLO CRIMEN)',
#        'ABUSO SEXUAL (SOLO CRIMEN)',
#        'MANEJO EN ESTADO DE EBRIEDAD (SOLO CRIMEN)',
#        'FALTAS AL REGIMEN PENITENCIARIO', 'VIOLACION (SOLO CRIMEN)',
#        'LESIONES LEVES', '(en blanco)', 'HURTO (SOLO CRIMEN)',
#        'NO REGISTRA CODIGO DE MATERIA'], dtype=object)

# %% [markdown]
# ## Caso 13001 -- > LESIONES LEVES

# %%
df_termino_materia['COD. MATERIA'] = df_termino_materia['COD. MATERIA'].replace(13001,13036)

# %% [markdown]
# ### Casos 4014, 4013, 4011, -31075, 4010, 0, 4007

# %%
filtro_codigo_4011 = df_termino_materia[df_termino_materia['COD. MATERIA']==4011]
filtro_codigo_4014 = df_termino_materia[df_termino_materia['COD. MATERIA']==4014]
filtro_codigo_4013 = df_termino_materia[df_termino_materia['COD. MATERIA']==4013]
filtro_codigo_4010 = df_termino_materia[df_termino_materia['COD. MATERIA']==4010]
filtro_codigo_31075 = df_termino_materia[df_termino_materia['COD. MATERIA']==31075]
filtro_codigo_4007 = df_termino_materia[df_termino_materia['COD. MATERIA']==4007]
filtro_codigo_0 = df_termino_materia[df_termino_materia['COD. MATERIA']==0]

# %%
df_termino_materia.drop(filtro_codigo_4011.index, axis = 0, inplace = True)
df_termino_materia.drop(filtro_codigo_4014.index, axis = 0, inplace = True)
df_termino_materia.drop(filtro_codigo_4013.index, axis = 0, inplace = True)
df_termino_materia.drop(filtro_codigo_4010.index, axis = 0, inplace = True)
df_termino_materia.drop(filtro_codigo_31075.index, axis = 0, inplace = True)
df_termino_materia.drop(filtro_codigo_4007.index, axis = 0, inplace = True)
df_termino_materia.drop(filtro_codigo_0.index, axis = 0, inplace = True)

# %%
pd.to_datetime(df_termino_materia['FECHA INGRESO'])
pd.to_datetime(df_termino_materia['FECHA TERMINO'])
# Out:
# 0         2018-06-01
# 1         2018-06-01
# 2         2018-08-29
# 3         2018-03-14
# 4         2018-05-29
#              ...
# 3603372   2016-05-21
# 3603373   2016-05-21
# 3603374   2016-11-08
# 3603375   2016-01-18
# 3603376   2016-09-16
# Name: FECHA TERMINO, Length: 3603336, dtype: datetime64[ns]

# %% [markdown]
# # Creacion Consolidado por Materia Penal
#
# Comenzaremos el analisis de la data consolidando la info en un unico DataSet, para ello vamos a considerar los siguientes puntos:
#
#
# - DATA:  Se considerará toda las causas que ingresaron al Sistema desde 2015 al 2019, esto ya que se cuenta además con la data de las audiencias en ese período.
#
#
# - No se consideran causas anteriores a este período.
#
# - Se considerarán Causas sin termino.

# %%
df_ingresos_materia.sort_values('FECHA INGRESO')
# Out:
#           index  COD. CORTE               CORTE  COD. TRIBUNAL  \
# 3033192  454022          90    C.A. DE SANTIAGO           1225
# 2893930  314651          50      C.A. DE TEMUCO            937
# 2893929  314650          50      C.A. DE TEMUCO            937
# 2893928  314649          50      C.A. DE TEMUCO            937
# 2893927  314648          50      C.A. DE TEMUCO            937
# ...         ...         ...                 ...            ...
# 760811   110188          30  C.A. DE VALPARAISO           1045
# 1146410  496058          90    C.A. DE SANTIAGO           1224
# 1146411  496059          90    C.A. DE SANTIAGO           1224
# 1041523  391063          55    C.A. DE VALDIVIA           1085
# 744493    93869          25   C.A. DE LA SERENA            930
#
#                                     TRIBUNAL         RIT TIPO CAUSA  \
# 3033192   SEXTO JUZGADO DE GARANTIA SANTIAGO      7-2015  Ordinaria
# 2893930           JUZGADO DE GARANTIA TEMUCO      6-2015  Ordinaria
# 2893929           JUZGADO DE GARANTIA TEMUCO      5-2015  Ordinaria
# 2893928           JUZGADO DE GARANTIA TEMUCO      4-2015  Ordinaria
# 2893927           JUZGADO DE GARANTIA TEMUCO      3-2015  Ordinaria
# ...                                      ...         ...        ...
# 760811        JUZGADO DE GARANTIA VALPARAISO  14411-2019  Ordinaria
# 1146410  QUINTO JUZGADO DE GARANTIA SANTIAGO   4799-2019  Ordinaria
# 1146411  QUINTO JUZGADO DE GARANTIA SANTIAGO   4800-2019  Ordinaria
# 1041523        JUZGADO DE GARANTIA MARIQUINA   1550-2019  Ordinaria
# 744493          JUZGADO DE GARANTIA COQUIMBO   6590-2019  Ordinaria
#
#          COD. MATERIA                                            MATERIA  \
# 3033192         12077  NO DAR CUENTA DE ACCIDENTE DE TRANSITOART. 195...
# 2893930          7037           TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).
# 2893929         13028                HURTO FALTA (494 BIS CODIGO PENAL).
# 2893928         14052  CONDUC. ESTADO DE EBRIEDAD CON O SIN DAÑOS O L...
# 2893927         13027               DAÑO FALTA (495 NR 21 CODIGO PENAL).
# ...               ...                                                ...
# 760811           7006  CULTIVO/COSECHA ESPEC.VEGETALES PRODUCTORAS ES...
# 1146410           524  AMENAZAS SIMPLES CONTRA PERSONAS Y PROPIEDADES...
# 1146411          1099  OTROS HECHOS QUE NO CONSTITUYAN DELITO: AGRUP....
# 1041523         13028                HURTO FALTA (494 BIS CODIGO PENAL).
# 744493            524  AMENAZAS SIMPLES CONTRA PERSONAS Y PROPIEDADES...
#
#         FECHA INGRESO MES INGRESO  AÑO INGRESO  TOTAL INGRESOS POR MATERIAS
# 3033192    2015-01-01      ene-15         2015                            1
# 2893930    2015-01-01      ene-15         2015                            1
# 2893929    2015-01-01      ene-15         2015                            1
# 2893928    2015-01-01      ene-15         2015                            1
# 2893927    2015-01-01      ene-15         2015                            1
# ...               ...         ...          ...                          ...
# 760811     2019-12-31      dic-19         2019                            1
# 1146410    2019-12-31      dic-19         2019                            1
# 1146411    2019-12-31      dic-19         2019                            1
# 1041523    2019-12-31      dic-19         2019                            1
# 744493     2019-12-31      dic-19         2019                            1
#
# [3210643 rows x 13 columns]

# %%
df_termino_materia.sort_values('FECHA INGRESO')
# Out:
#           index  COD. CORTE                 CORTE  COD. TRIBUNAL  \
# 433047   433419          56  C.A. DE PUERTO MONTT            662
# 324194   324466          46    C.A. DE CONCEPCION           1080
# 364405   364702          50        C.A. DE TEMUCO            214
# 1538565   97453          25     C.A. DE LA SERENA            932
# 1541216  100104          25     C.A. DE LA SERENA            932
# ...         ...         ...                   ...            ...
# 1132871  403096          55      C.A. DE VALDIVIA            226
# 1132870  403095          55      C.A. DE VALDIVIA            226
# 1132869  403094          55      C.A. DE VALDIVIA            226
# 1134540  404767          55      C.A. DE VALDIVIA            227
# 763368    33286          11       C.A. DE IQUIQUE           1500
#
#                                            TRIBUNAL        RIT TIPO CAUSA  \
# 433047         JUZGADO DE LETRAS Y GARANTIA QUELLON   684-2018  Ordinaria
# 324194               JUZGADO DE GARANTIA TALCAHUANO  2398-2017  Ordinaria
# 364405           JUZGADO DE LETRAS Y GARANTIA PUCON  1059-2017  Ordinaria
# 1538565                  JUZGADO DE GARANTIA OVALLE     1-2000  Ordinaria
# 1541216                  JUZGADO DE GARANTIA OVALLE     3-2000  Ordinaria
# ...                                             ...        ...        ...
# 1132871       JUZGADO DE LETRAS Y GARANTIA LA UNION  1726-2019  Ordinaria
# 1132870       JUZGADO DE LETRAS Y GARANTIA LA UNION  1725-2019  Ordinaria
# 1132869       JUZGADO DE LETRAS Y GARANTIA LA UNION  1724-2019  Ordinaria
# 1134540      JUZGADO DE LETRAS Y GARANTIA RIO BUENO  1463-2019  Ordinaria
# 763368   JUZGADO DE LETRAS Y GARANTIA ALTO HOSPICIO  4839-2019  Ordinaria
#
#          COD. MATERIA                                            MATERIA  \
# 433047            518       PORTE DE ARMA CORTANTE O PUNZANTE (288 BIS).
# 324194            848  HURTO SIMPLE POR UN VALOR DE MEDIA A MENOS DE ...
# 364405            710                             LESIONES MENOS GRAVES.
# 1538565           801                                       HURTO SIMPLE
# 1541216           613                                 ABUSOS DESHONESTOS
# ...               ...                                                ...
# 1132871           524  AMENAZAS SIMPLES CONTRA PERSONAS Y PROPIEDADES...
# 1132870         12152  APROPIACION DE COTIZAC.PREVISIONALES Y DECLARA...
# 1132869         13027               DAÑO FALTA (495 NR 21 CODIGO PENAL).
# 1134540           799                  OTROS DELITOS CONTRA LAS PERSONAS
# 763368            623  ABUSO SEXUAL CON CONTACTO DE MENOR DE 14 AÑOS....
#
#         FECHA INGRESO FECHA TERMINO MES TERMINO  AÑO TERMINO  \
# 433047     1900-01-01    2018-08-21      ago-18         2018
# 324194     1900-01-01    2018-05-31      may-18         2018
# 364405     1900-01-01    2018-10-01      oct-18         2018
# 1538565    2000-12-20    2015-06-02      jun-15         2015
# 1541216    2000-12-21    2015-06-02      jun-15         2015
# ...               ...           ...         ...          ...
# 1132871    2019-12-31    2019-12-31      dic-19         2019
# 1132870    2019-12-31    2019-12-31      dic-19         2019
# 1132869    2019-12-31    2019-12-31      dic-19         2019
# 1134540    2019-12-31    2019-12-31      dic-19         2019
# 763368     2019-12-31    2019-12-31      dic-19         2019
#
#                                             MOTIVO TERMINO  DURACION CAUSA  \
# 433047                                           SENTENCIA          -22204
# 324194                  DECLARA SOBRESEIMIENTO DEFINITIVO.          -22286
# 364405                  DECLARA SOBRESEIMIENTO DEFINITIVO.          -22163
# 1538565                   CERTIFICA CUMPLIMIENTO ART. 468.            5277
# 1541216                 NO PERSEVERAR EN EL PROCEDIMIENTO.            5276
# ...                                                    ...             ...
# 1132871                APROBACION NO INICIO INVESTIGACION.               0
# 1132870                APROBACION NO INICIO INVESTIGACION.               0
# 1132869  COMUNICA Y/O APLICA DECISION PPIO. DE OPORTUNI...               0
# 1134540                APROBACION NO INICIO INVESTIGACION.               0
# 763368                 APROBACION NO INICIO INVESTIGACION.               0
#
#          TOTAL TERMINOS
# 433047                1
# 324194                1
# 364405                1
# 1538565               1
# 1541216               1
# ...                 ...
# 1132871               1
# 1132870               1
# 1132869               1
# 1134540               1
# 763368                1
#
# [3603336 rows x 16 columns]

# %% [markdown]
# ##### Verifico si existen Causas sin Fechas de inicio

# %%
filtro = df_ingresos_materia[df_ingresos_materia['FECHA INGRESO'].isnull()]

# %%
print(f"Existen: {len(filtro)} causas con Fechas Ingreso Null")
# Out:
# Existen: 0 causas con Fechas Ingreso Null

# %% [markdown]
# ##### Verifico si existen Causas con Fechas de inicio con NULL en Termino_Materia

# %%
filtro_null = df_termino_materia[df_termino_materia['FECHA INGRESO'].isnull()]
print(f"Existen {len(filtro_null)} causas con Fecha Ingreso Null")
# Out:
# Existen 0 causas con Fecha Ingreso Null

# %% [markdown]
# Elimino las filas con valores nulos

# %%
df_termino_materia.drop(filtro_null.index, axis = 0, inplace = True)

# %% [markdown]
# Verifico las causas con Fecha Ingreso anterior a 01-01-2015

# %%
filtro_fechas = df_termino_materia[df_termino_materia['FECHA INGRESO'] <= '2014-12-31']
print(f"Existen {len(filtro_fechas)} causas con Fecha Ingreso anteriores al 31-12-2014 que no deben ser considerada")
# Out:
# Existen 462068 causas con Fecha Ingreso anteriores al 31-12-2014 que no deben ser considerada

# %% [markdown]
# Elimino las causas con Fecha de Ingreso anterior a 31-12-2014

# %%
df_termino_materia.drop(filtro_fechas.index, axis = 0, inplace = True)

# %%
df_termino_materia
# Out:
#           index  COD. CORTE               CORTE  COD. TRIBUNAL  \
# 0             0          10       C.A. DE ARICA            988
# 1             1          10       C.A. DE ARICA            988
# 2             2          10       C.A. DE ARICA            988
# 3             3          10       C.A. DE ARICA            988
# 4             4          10       C.A. DE ARICA            988
# ...         ...         ...                 ...            ...
# 3603372  721902          91  C.A. DE SAN MIGUEL           1355
# 3603373  721903          91  C.A. DE SAN MIGUEL           1355
# 3603374  721904          91  C.A. DE SAN MIGUEL           1355
# 3603375  721905          91  C.A. DE SAN MIGUEL           1355
# 3603376  721906          91  C.A. DE SAN MIGUEL           1355
#
#                                               TRIBUNAL       RIT TIPO CAUSA  \
# 0            TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  100-2018  Ordinaria
# 1            TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  100-2018  Ordinaria
# 2            TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  101-2018  Ordinaria
# 3            TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA   10-2018  Ordinaria
# 4            TRIBUNAL DE JUICIO ORAL EN LO PENAL ARICA  102-2018  Ordinaria
# ...                                                ...       ...        ...
# 3603372  TRIBUNAL DE JUICIO ORAL EN LO PENAL MELIPILLA   98-2015  Ordinaria
# 3603373  TRIBUNAL DE JUICIO ORAL EN LO PENAL MELIPILLA   98-2015  Ordinaria
# 3603374  TRIBUNAL DE JUICIO ORAL EN LO PENAL MELIPILLA   98-2016  Ordinaria
# 3603375  TRIBUNAL DE JUICIO ORAL EN LO PENAL MELIPILLA   99-2015  Ordinaria
# 3603376  TRIBUNAL DE JUICIO ORAL EN LO PENAL MELIPILLA   99-2016  Ordinaria
#
#          COD. MATERIA                                            MATERIA  \
# 0                7007                TRAFICO ILICITO DE DROGAS (ART. 3).
# 1               10004  PORTE ILEGAL DE ARMA DE FUEGO, MUNICIONES Y OT...
# 2               12149  DESACATO (ART. 240 CODIGO DE PROCEDIMIENTO CIV...
# 3                7037           TRAFICO DE PEQUEÑAS CANTIDADES (ART. 4).
# 4                 812                       RECEPTACION. ART. 456 BIS A.
# ...               ...                                                ...
# 3603372           901  CUASIDELITO DE LESIONES: ART 490, 491 INC 2° Y...
# 3603373         12077  NO DAR CUENTA DE ACCIDENTE DE TRANSITOART. 195...
# 3603374         10008          PORTE DE ARMA PROHIBIDA (ART. 14 INC. 1°)
# 3603375         12082   AMENAZASA CARABINEROS (ART. 417 COD. J.MILITAR).
# 3603376           812                       RECEPTACION. ART. 456 BIS A.
#
#         FECHA INGRESO FECHA TERMINO MES TERMINO  AÑO TERMINO MOTIVO TERMINO  \
# 0          2018-04-02    2018-06-01      jun-18         2018      SENTENCIA
# 1          2018-04-02    2018-06-01      jun-18         2018      SENTENCIA
# 2          2018-04-02    2018-08-29      ago-18         2018      SENTENCIA
# 3          2018-01-10    2018-03-14      mar-18         2018      SENTENCIA
# 4          2018-04-02    2018-05-29      may-18         2018      SENTENCIA
# ...               ...           ...         ...          ...            ...
# 3603372    2015-12-17    2016-05-21      may-16         2016      SENTENCIA
# 3603373    2015-12-17    2016-05-21      may-16         2016      SENTENCIA
# 3603374    2016-07-27    2016-11-08      nov-16         2016      SENTENCIA
# 3603375    2015-12-17    2016-01-18      ene-16         2016      SENTENCIA
# 3603376    2016-08-03    2016-09-16     sept-16         2016      SENTENCIA
#
#          DURACION CAUSA  TOTAL TERMINOS
# 0                    60               1
# 1                    60               1
# 2                   149               1
# 3                    63               1
# 4                    57               1
# ...                 ...             ...
# 3603372             156               1
# 3603373             156               1
# 3603374             104               1
# 3603375              32               1
# 3603376              44               1
#
# [3141268 rows x 16 columns]

# %% [markdown]
# Verifico si existen Causas con duracion negativo, esto se debe a error en Sistema y debe cambiar el orden.

# %%
df_termino_materia[df_termino_materia['DURACION CAUSA']<0]
# Out:
#           index  COD. CORTE               CORTE  COD. TRIBUNAL  \
# 793         793          10       C.A. DE ARICA            992
# 794         794          10       C.A. DE ARICA            992
# 795         795          10       C.A. DE ARICA            992
# 796         796          10       C.A. DE ARICA            992
# 1084       1084          10       C.A. DE ARICA            992
# ...         ...         ...                 ...            ...
# 3602454  720984          91  C.A. DE SAN MIGUEL           1322
# 3602474  721004          91  C.A. DE SAN MIGUEL           1322
# 3602475  721005          91  C.A. DE SAN MIGUEL           1322
# 3602476  721006          91  C.A. DE SAN MIGUEL           1322
# 3602477  721007          91  C.A. DE SAN MIGUEL           1322
#
#                                                 TRIBUNAL         RIT  \
# 793                            JUZGADO DE GARANTIA ARICA  10153-2018
# 794                            JUZGADO DE GARANTIA ARICA  10154-2018
# 795                            JUZGADO DE GARANTIA ARICA  10155-2018
# 796                            JUZGADO DE GARANTIA ARICA  10156-2018
# 1084                           JUZGADO DE GARANTIA ARICA  10413-2018
# ...                                                  ...         ...
# 3602454  TRIBUNAL DE JUICIO ORAL EN LO PENAL PUENTE ALTO    137-2016
# 3602474  TRIBUNAL DE JUICIO ORAL EN LO PENAL PUENTE ALTO    159-2016
# 3602475  TRIBUNAL DE JUICIO ORAL EN LO PENAL PUENTE ALTO    159-2016
# 3602476  TRIBUNAL DE JUICIO ORAL EN LO PENAL PUENTE ALTO    159-2016
# 3602477  TRIBUNAL DE JUICIO ORAL EN LO PENAL PUENTE ALTO    159-2016
#
#         TIPO CAUSA  COD. MATERIA  \
# 793      Ordinaria           905
# 794      Ordinaria           808
# 795      Ordinaria           710
# 796      Ordinaria           710
# 1084     Ordinaria          7007
# ...            ...           ...
# 3602454  Ordinaria          7007
# 3602474  Ordinaria          7007
# 3602475  Ordinaria          7007
# 3602476  Ordinaria          7007
# 3602477  Ordinaria          7007
#
#                                                    MATERIA FECHA INGRESO  \
# 793                              CUASIDELITO DE HOMICIDIO.    2018-12-11
# 794      ROBO EN BIENES NACIONALES DE USO PUBLICO O SIT...    2018-12-11
# 795                                 LESIONES MENOS GRAVES.    2018-12-11
# 796                                 LESIONES MENOS GRAVES.    2018-12-11
# 1084                   TRAFICO ILICITO DE DROGAS (ART. 3).    2018-12-20
# ...                                                    ...           ...
# 3602454                TRAFICO ILICITO DE DROGAS (ART. 3).    2016-10-28
# 3602474                TRAFICO ILICITO DE DROGAS (ART. 3).    2016-11-30
# 3602475                TRAFICO ILICITO DE DROGAS (ART. 3).    2016-11-30
# 3602476                TRAFICO ILICITO DE DROGAS (ART. 3).    2016-11-30
# 3602477                TRAFICO ILICITO DE DROGAS (ART. 3).    2016-11-30
#
#         FECHA TERMINO MES TERMINO  AÑO TERMINO          MOTIVO TERMINO  \
# 793        2018-11-30      nov-18         2018  DECLARA INCOMPETENCIA.
# 794        2018-11-30      nov-18         2018  DECLARA INCOMPETENCIA.
# 795        2018-12-03      dic-18         2018  DECLARA INCOMPETENCIA.
# 796        2018-12-03      dic-18         2018  DECLARA INCOMPETENCIA.
# 1084       2018-12-05      dic-18         2018  DECLARA INCOMPETENCIA.
# ...               ...         ...          ...                     ...
# 3602454    2016-10-26      oct-16         2016  DECLARA INCOMPETENCIA.
# 3602474    2016-08-30      ago-16         2016  DECLARA INCOMPETENCIA.
# 3602475    2016-09-15     sept-16         2016  DECLARA INCOMPETENCIA.
# 3602476    2016-10-03      oct-16         2016  DECLARA INCOMPETENCIA.
# 3602477    2016-10-12      oct-16         2016  DECLARA INCOMPETENCIA.
#
#          DURACION CAUSA  TOTAL TERMINOS
# 793                 -11               1
# 794                 -11               1
# 795                  -8               1
# 796                  -8               1
# 1084                -15               1
# ...                 ...             ...
# 3602454              -2               1
# 3602474             -92               1
# 3602475             -76               1
# 3602476             -58               1
# 3602477             -49               1
#
# [56505 rows x 16 columns]

# %%
df_termino_materia = df_termino_materia.progress_apply(transformdata.fechas_cambiadas, axis=1)
# Out:
# 100%|██████████| 3141268/3141268 [03:17<00:00, 15874.40it/s]

# %%
df_termino_materia[df_termino_materia['DURACION CAUSA']<0]
# Out:
# Empty DataFrame
# Columns: [index, COD. CORTE, CORTE, COD. TRIBUNAL, TRIBUNAL, RIT, TIPO CAUSA, COD. MATERIA, MATERIA, FECHA INGRESO, FECHA TERMINO, MES TERMINO, AÑO TERMINO, MOTIVO TERMINO, DURACION CAUSA, TOTAL TERMINOS]
# Index: []

# %%
df_ingresos_materia['AÑO INGRESO'].value_counts()
# Out:
# 2019    666961
# 2018    650653
# 2016    631379
# 2015    631261
# 2017    630389
# Name: AÑO INGRESO, dtype: int64

# %%
df_termino_materia[df_termino_materia['FECHA INGRESO']<'01-01-2015']
# Out:
# Empty DataFrame
# Columns: [index, COD. CORTE, CORTE, COD. TRIBUNAL, TRIBUNAL, RIT, TIPO CAUSA, COD. MATERIA, MATERIA, FECHA INGRESO, FECHA TERMINO, MES TERMINO, AÑO TERMINO, MOTIVO TERMINO, DURACION CAUSA, TOTAL TERMINOS]
# Index: []

# %% [markdown]
# ## CARGA DATA A ARCHIVOS FUTHER

# %%
# Directorio donde se guardaran archivos feather
df_ingresos_materia.reset_index(inplace=True, drop=True)
df_termino_materia.reset_index(inplace=True, drop=True)
os.makedirs(path_processed, exist_ok = True)  

# Guardamos dataset como archivo feather

df_ingresos_materia.to_feather(f'{path_processed}/processes_IngresosMateria.feather')
df_termino_materia.to_feather(f'{path_processed}/processes_TerminosMateria.feather')

# %% [markdown]
# # Generación de Data Única referente a Audiencias
#
# Transformación de algunos datos para normalizar nombres en columnas

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
from unicodedata import normalize

from src.data import cleandata
from src.data import transformdata

# %%
tqdm.pandas()

path_interim = "../data/interim/pjud"
path_processed = "../data/processed/pjud"
# Out:
# /Users/jalvaradoruiz/opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# # DATA de TRIBUNALES OBTENIDAS DEL COT

# %%
# Analizo contra los datos extraidos en COT
df_tribunales = pd.read_feather(f"{path_processed}/ListadoTribunales_feather")
tribunales = df_tribunales['TRIBUNAL'].unique()

# %% [markdown]
# # DATA AUDIENCIAS

# %%
df_audiencias = pd.read_feather(f"{path_interim}/Audiencias_feather")
df_audiencias.sort_values('FECHA PROGRAMACION AUDIENCIA')
# Out:
#            index  COD. CORTE                 CORTE  COD. TRIBUNAL  \
# 5911937  1028429          56  C.A. DE PUERTO MONTT           1090
# 5909127  1025242          56  C.A. DE PUERTO MONTT           1090
# 5906737  1022513          56  C.A. DE PUERTO MONTT           1090
# 5022886    57134          15   C.A. DE ANTOFAGASTA            952
# 625821    683790          10         C.A. DE ARICA            992
# ...          ...         ...                   ...            ...
# 3747420  1334990          91    C.A. DE SAN MIGUEL           1240
# 3747422  1334992          91    C.A. DE SAN MIGUEL           1240
# 3747425  1334995          91    C.A. DE SAN MIGUEL           1240
# 3747426  1334996          91    C.A. DE SAN MIGUEL           1240
# 3747427  1334997          91    C.A. DE SAN MIGUEL           1240
#
#                                     TRIBUNAL        RIT TIPO CAUSA  \
# 5911937  JUZGADO DE GARANTIA DE PUERTO MONTT   624-2006  Ordinaria
# 5909127  JUZGADO DE GARANTIA DE PUERTO MONTT  3818-2006  Ordinaria
# 5906737  JUZGADO DE GARANTIA DE PUERTO MONTT  1026-2005  Ordinaria
# 5022886   JUZGADO DE GARANTIA DE ANTOFAGASTA  6143-2007  Ordinaria
# 625821          JUZGADO DE GARANTIA DE ARICA  1804-2006  Ordinaria
# ...                                      ...        ...        ...
# 3747420     JUZGADO DE GARANTIA DE TALAGANTE   994-2016  Ordinaria
# 3747422     JUZGADO DE GARANTIA DE TALAGANTE   997-2017  Ordinaria
# 3747425     JUZGADO DE GARANTIA DE TALAGANTE   998-2017  Ordinaria
# 3747426     JUZGADO DE GARANTIA DE TALAGANTE   998-2017  Ordinaria
# 3747427     JUZGADO DE GARANTIA DE TALAGANTE   998-2017  Ordinaria
#
#                                  TIPO DE AUDIENCIA  \
# 5911937   AUDIENCIA DE COMUNI. NO PERSEV.  PROCED.
# 5909127           AUDIENCIA DE MEDIDAS CAUTELARES.
# 5906737      AUDIENCIA DE PROCEDIMIENTO ABREVIADO.
# 5022886      AUDIENCIA DE PREPARACION JUICIO ORAL.
# 625821                AUDIENCIA DE SOBRESEIMIENTO.
# ...                                            ...
# 3747420                   AUDIENCIA DE LEY 18.216.
# 3747422  AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
# 3747425  AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
# 3747426  AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
# 3747427  AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
#
#         FECHA PROGRAMACION AUDIENCIA FECHA AUDIENCIA  DIAS AGENDAMIENTO  \
# 5911937                   2007-04-25      2015-10-23               3103
# 5909127                   2007-07-30      2015-10-15               2999
# 5906737                   2008-02-14      2015-10-23               2808
# 5022886                   2008-03-31      2015-06-18               2635
# 625821                    2008-10-01      2018-08-24               3614
# ...                              ...             ...                ...
# 3747420                          NaT      2017-09-13                 21
# 3747422                          NaT      2017-12-04                 39
# 3747425                          NaT      2017-10-05                 38
# 3747426                          NaT      2017-11-16                 42
# 3747427                          NaT      2017-12-20                 34
#
#         DURACION AUDIENCIA (MIN)  TOTAL AUDIENCIAS
# 5911937                        1                 1
# 5909127                        2                 1
# 5906737                        5                 1
# 5022886                        5                 1
# 625821                        15                 1
# ...                          ...               ...
# 3747420                        2                 1
# 3747422                        1                 1
# 3747425                        2                 1
# 3747426                        5                 1
# 3747427                        5                 1
#
# [6169226 rows x 13 columns]

# %%
df_audiencias[df_audiencias['FECHA PROGRAMACION AUDIENCIA'].isnull()]
# Out:
#            index  COD. CORTE               CORTE  COD. TRIBUNAL  \
# 2521995      888          10       C.A. DE ARICA            992
# 2522080      974          10       C.A. DE ARICA            992
# 2522120     1014          10       C.A. DE ARICA            992
# 2522123     1018          10       C.A. DE ARICA            992
# 2522142     1039          10       C.A. DE ARICA            992
# ...          ...         ...                 ...            ...
# 3747420  1334990          91  C.A. DE SAN MIGUEL           1240
# 3747422  1334992          91  C.A. DE SAN MIGUEL           1240
# 3747425  1334995          91  C.A. DE SAN MIGUEL           1240
# 3747426  1334996          91  C.A. DE SAN MIGUEL           1240
# 3747427  1334997          91  C.A. DE SAN MIGUEL           1240
#
#                                  TRIBUNAL         RIT TIPO CAUSA  \
# 2521995      JUZGADO DE GARANTIA DE ARICA  10028-2016  Ordinaria
# 2522080      JUZGADO DE GARANTIA DE ARICA  10078-2016  Ordinaria
# 2522120      JUZGADO DE GARANTIA DE ARICA  10098-2016  Ordinaria
# 2522123      JUZGADO DE GARANTIA DE ARICA  10099-2016  Ordinaria
# 2522142      JUZGADO DE GARANTIA DE ARICA  10109-2016  Ordinaria
# ...                                   ...         ...        ...
# 3747420  JUZGADO DE GARANTIA DE TALAGANTE    994-2016  Ordinaria
# 3747422  JUZGADO DE GARANTIA DE TALAGANTE    997-2017  Ordinaria
# 3747425  JUZGADO DE GARANTIA DE TALAGANTE    998-2017  Ordinaria
# 3747426  JUZGADO DE GARANTIA DE TALAGANTE    998-2017  Ordinaria
# 3747427  JUZGADO DE GARANTIA DE TALAGANTE    998-2017  Ordinaria
#
#                                        TIPO DE AUDIENCIA  \
# 2521995         AUDIENCIA DE PROCEDIMIENTO SIMPLIFICADO.
# 2522080        AUDIENCIA DE REVISION PRISION PREVENTIVA.
# 2522120         AUDIENCIA DE PROCEDIMIENTO SIMPLIFICADO.
# 2522123  AUDIENCIA DE CONTROL DE PLAZO DE INVESTIGACION.
# 2522142         AUDIENCIA DE PROCEDIMIENTO SIMPLIFICADO.
# ...                                                  ...
# 3747420                         AUDIENCIA DE LEY 18.216.
# 3747422        AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
# 3747425        AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
# 3747426        AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
# 3747427        AUDIENCIA DE FORMAL. DE LA INVESTIGACISN.
#
#         FECHA PROGRAMACION AUDIENCIA FECHA AUDIENCIA  DIAS AGENDAMIENTO  \
# 2521995                          NaT      2017-03-07                 21
# 2522080                          NaT      2017-05-04                 42
# 2522120                          NaT      2017-05-16                 53
# 2522123                          NaT      2017-03-28                 29
# 2522142                          NaT      2017-04-27                 43
# ...                              ...             ...                ...
# 3747420                          NaT      2017-09-13                 21
# 3747422                          NaT      2017-12-04                 39
# 3747425                          NaT      2017-10-05                 38
# 3747426                          NaT      2017-11-16                 42
# 3747427                          NaT      2017-12-20                 34
#
#         DURACION AUDIENCIA (MIN)  TOTAL AUDIENCIAS
# 2521995                        2                 1
# 2522080                        3                 1
# 2522120                        1                 1
# 2522123                       12                 1
# 2522142                        8                 1
# ...                          ...               ...
# 3747420                        2                 1
# 3747422                        1                 1
# 3747425                        2                 1
# 3747426                        5                 1
# 3747427                        5                 1
#
# [303848 rows x 13 columns]

# %% [markdown]
# Existen audiencias soin FECHA PROGRAMACION AUDIENCIA, pero se cuenta con la fecha de la AUDIENCIA y además con DIAS AGENDAMIENTO, por lo que se puede acceder.

# %%
df_audiencias = df_audiencias.progress_apply(transformdata.fecha_programada, axis=1)
# Out:
# 100%|██████████| 6169226/6169226 [21:01<00:00, 4891.94it/s]

# %%
filtro_fecha = df_audiencias[df_audiencias['FECHA PROGRAMACION AUDIENCIA']<='2014-12-31']
print(f"Existen {len(filtro_fecha)} AUDIENCIAS programadas antes del 01-01-2015")
# Out:
# Existen 85944 AUDIENCIAS programadas antes del 01-01-2015

# %%
df_audiencias.drop(filtro_fecha.index, axis=0, inplace=True)

# %%
# Normalizo nombres

df_audiencias['TRIBUNAL'] = df_audiencias['TRIBUNAL'].progress_apply(cleandata.cambio_nombre_juzgados)
# Out:
# 100%|██████████| 6083282/6083282 [00:33<00:00, 180486.44it/s]

# %%
# Verifico si coinciden los nombres e imprimo los que estan en conflicto

for tribunal in df_audiencias['TRIBUNAL'].unique():
    if not tribunal in tribunales:
        print(tribunal)

# %% [markdown]
# Verifico si existen audiencias de causas del período anterior a 2015

# %%
años = range(2000,2015)
fuera_rango = []

for año in range(len(años)):
    var = "-" + str(años[año])
    fuera_rango.append(df_audiencias[df_audiencias['RIT'].str.contains(var)])

# %%
df_eliminar = pd.concat(fuera_rango, axis=0)

# %%
df_eliminar
# Out:
#            index  COD. CORTE               CORTE  COD. TRIBUNAL  \
# 935762   1022586          50      C.A. DE TEMUCO            937
# 937211   1024327          50      C.A. DE TEMUCO            937
# 937746   1024864          50      C.A. DE TEMUCO            937
# 937800   1024920          50      C.A. DE TEMUCO            937
# 937826   1024946          50      C.A. DE TEMUCO            937
# ...          ...         ...                 ...            ...
# 6168948  1305107          91  C.A. DE SAN MIGUEL           1323
# 6168949  1305108          91  C.A. DE SAN MIGUEL           1323
# 6168950  1305109          91  C.A. DE SAN MIGUEL           1323
# 6169076  1305235          91  C.A. DE SAN MIGUEL           1323
# 6169105  1305264          91  C.A. DE SAN MIGUEL           1355
#
#                                                  TRIBUNAL        RIT  \
# 935762                         JUZGADO DE GARANTIA TEMUCO  1070-2001
# 937211                         JUZGADO DE GARANTIA TEMUCO  1258-2001
# 937746                         JUZGADO DE GARANTIA TEMUCO  1714-2001
# 937800                         JUZGADO DE GARANTIA TEMUCO  1758-2001
# 937826                         JUZGADO DE GARANTIA TEMUCO  1767-2001
# ...                                                   ...        ...
# 6168948  TRIBUNAL DE JUICIO ORAL EN LO PENAL SAN BERNARDO    52-2014
# 6168949  TRIBUNAL DE JUICIO ORAL EN LO PENAL SAN BERNARDO    52-2014
# 6168950  TRIBUNAL DE JUICIO ORAL EN LO PENAL SAN BERNARDO    52-2014
# 6169076  TRIBUNAL DE JUICIO ORAL EN LO PENAL SAN BERNARDO    98-2014
# 6169105     TRIBUNAL DE JUICIO ORAL EN LO PENAL MELIPILLA    44-2014
#
#         TIPO CAUSA                            TIPO DE AUDIENCIA  \
# 935762   Ordinaria  AUDIENCIA DE CONOCIMIENTO DE INVESTIGACION.
# 937211   Ordinaria  AUDIENCIA DE CONOCIMIENTO DE INVESTIGACION.
# 937746   Ordinaria  AUDIENCIA DE CONOCIMIENTO DE INVESTIGACION.
# 937800   Ordinaria  AUDIENCIA DE CONOCIMIENTO DE INVESTIGACION.
# 937826   Ordinaria  AUDIENCIA DE CONOCIMIENTO DE INVESTIGACION.
# ...            ...                                          ...
# 6168948  Ordinaria      AUDIENCIA DE CONTROL DE EJECUCION (RPA)
# 6168949  Ordinaria      AUDIENCIA DE CONTROL DE EJECUCION (RPA)
# 6168950  Ordinaria      AUDIENCIA DE CONTROL DE EJECUCION (RPA)
# 6169076  Ordinaria                 AUDIENCIA DE JUICIO ORAL TOP
# 6169105  Ordinaria     AUDIENCIA PARA REV.  DE LA SENT. Y PENAS
#
#         FECHA PROGRAMACION AUDIENCIA FECHA AUDIENCIA  DIAS AGENDAMIENTO  \
# 935762                    2018-11-09      2018-11-16                  7
# 937211                    2018-11-20      2018-12-27                 37
# 937746                    2018-11-20      2018-12-27                 37
# 937800                    2018-11-20      2018-12-27                 37
# 937826                    2018-11-26      2018-12-27                 31
# ...                              ...             ...                ...
# 6168948                   2015-06-24      2015-07-08                 14
# 6168949                   2015-06-24      2015-07-08                 14
# 6168950                   2015-07-08      2015-07-22                 14
# 6169076                   2015-07-15      2015-09-02                 49
# 6169105                   2015-10-13      2015-10-22                  9
#
#         DURACION AUDIENCIA (MIN)  TOTAL AUDIENCIAS
# 935762                         4                 1
# 937211                         0                 1
# 937746                         0                 1
# 937800                         0                 1
# 937826                         0                 1
# ...                          ...               ...
# 6168948                        2                 1
# 6168949                       19                 1
# 6168950                       26                 1
# 6169076                        9                 1
# 6169105                       52                 1
#
# [761305 rows x 13 columns]

# %%
print(f"Existen {len(df_eliminar)} audiencias del periodo anterior a 2015, estas se deben eliminar del dataset Audiencias")
# Out:
# Existen 761305 audiencias del periodo anterior a 2015, estas se deben eliminar del dataset Audiencias

# %%
df_audiencias.drop(df_eliminar.index, axis=0, inplace=True)

# %% [markdown]
# ## CARGA DATA A ARCHIVOS FUTHER

# %%
# Directorio donde se guardaran archivos feather
df_audiencias.reset_index(inplace = True)
os.makedirs(path_processed, exist_ok = True)  

# Guardamos dataset como archivo feather
df_audiencias.to_feather(f'{path_processed}/Audiencias_feather')
